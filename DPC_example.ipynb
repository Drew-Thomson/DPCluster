# %%
from dpcluster import Densitycluster
from dpcluster.plotting import plot_decision_graph, plot_clusters_3d

# %%
import random

# %%
centres = [[1, 0, 4],
          [-2, 5, -3],
          [6, -2, 0],
          [-5, 4, -3]]

sigmas = [[0.5, 1, 0.1],
         [0.3, 2, 1],
         [0.5, 0.5, 0.5],
         [1, 0.1, 0.5]]

fake_data = []
for i in range(2000):
    index = random.randint(0, 3)
    entry = [random.gauss(centres[index][x], sigmas[index][x]) for x in range(len(centres[0]))]
    fake_data.append(entry)

# %%
# Example usage
model = Densitycluster(fake_data)
model.build_dist_matrix()
model.assign_rho_delta(delta_cut=0.075,rho_cut=0.1,grad=0,cutoff_dist=.4)
plot_decision_graph(model)
# Out:
# distance matrix built in 0.0340 seconds
# delta and rho assigned in 3.9364 seconds

# %%
model.run_clustering()
plot_clusters_3d(model)
# Out:
# there were 1834 points to cluster
# there were 3 points excluded
# clusters assigned in 0.9986 seconds
# found 4 clusters
# clusters contain [501, 467, 482, 388] entries

# %%
model.cluster_centre_idx
# Out:
# array([ 740,  858, 1504, 1658])

# %%
model.clusters
# Out:
# [[740,
#   536,
#   810,
#   891,
#   1185,
#   1425,
#   1440,
#   1468,
#   1777,
#   1802,
#   1842,
#   1971,
#   86,
#   94,
#   101,
#   192,
#   246,
#   325,
#   600,
#   658,
#   663,
#   701,
#   775,
#   776,
#   796,
#   821,
#   830,
#   900,
#   905,
#   987,
#   1050,
#   1059,
#   1138,
#   1269,
#   1271,
#   1285,
#   1493,
#   1508,
#   1628,
#   1686,
#   1744,
#   1853,
#   1860,
#   1901,
#   1930,
#   1991,
#   0,
#   61,
#   98,
#   302,
#   336,
#   343,
#   346,
#   381,
#   404,
#   493,
#   505,
#   558,
#   578,
#   632,
#   660,
#   700,
#   849,
#   952,
#   983,
#   1055,
#   1070,
#   1114,
#   1119,
#   1132,
#   1133,
#   1142,
#   1158,
#   1213,
#   1224,
#   1226,
#   1294,
#   1299,
#   1310,
#   1330,
#   1331,
#   1362,
#   1371,
#   1393,
#   1400,
#   1406,
#   1444,
#   1451,
#   1502,
#   1503,
#   1587,
#   1672,
#   1691,
#   1698,
#   1706,
#   1707,
#   1776,
#   1807,
#   1823,
#   1837,
#   1845,
#   32,
#   81,
#   131,
#   197,
# ...

# %%
model.excluded
# Out:
# array([292, 504, 806])
